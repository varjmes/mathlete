# %%
# %load_ext tikzmagic

# %%
# %%tikz
# \usetikzlibrary{angles,quotes,through, calc}
# \coordinate [label=left:$A$](a) at (0,0);
# \coordinate [label=right:$B$](b) at (5,0);
# \draw[thick] (a) -- (b);
# \draw (2,0) +(0:1.5cm) arc (0:180:1cm);
# \draw (2,0) +(0:0.70cm) arc (0:180:0.2cm);
# \node at (2.55,0.5) {$180^{\circ}$};
# \draw (2,0) +(0:1.5cm) arc (0:-180:1cm);
# \draw (2,0) +(0:0.70cm) arc (0:-180:0.2cm);
# \node at (2.55,-0.5) {$180^{\circ}$};
